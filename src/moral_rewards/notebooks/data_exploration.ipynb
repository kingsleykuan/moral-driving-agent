# %% [markdown]
# # Moral Machine Data Exploration

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data_path = 'FilteredSharedResponses.csv'
data = pd.read_csv(data_path, sep=',', header=0)
data['Man'] = pd.to_numeric(data['Man'], downcast='integer')
data.columns
# Out:
# Index(['ResponseID', 'ExtendedSessionID', 'UserID', 'ScenarioOrder',
#        'Intervention', 'PedPed', 'Barrier', 'CrossingSignal', 'AttributeLevel',
#        'ScenarioTypeStrict', 'ScenarioType', 'DefaultChoice',
#        'NonDefaultChoice', 'DefaultChoiceIsOmission', 'NumberOfCharacters',
#        'DiffNumberOFCharacters', 'Saved', 'Template', 'DescriptionShown',
#        'LeftHand', 'UserCountry3', 'Man', 'Woman', 'Pregnant', 'Stroller',
#        'OldMan', 'OldWoman', 'Boy', 'Girl', 'Homeless', 'LargeWoman',
#        'LargeMan', 'Criminal', 'MaleExecutive', 'FemaleExecutive',
#        'FemaleAthlete', 'MaleAthlete', 'FemaleDoctor', 'MaleDoctor', 'Dog',
#        'Cat'],
#       dtype='object')

# %% [markdown]
# A user takes part in 1 or more sessions, each consisting of 1-13 pairs of scenarios.
#
# - User
#     - 1+ Sessions
#         - 1-13 Responses
#             - 2 Scenarios
#
# ## Column Details
#
# Each row details the lane in which the car will crash into.
#
# ### Response Metadata
# - ResponseID - ID of the response that this scenario belongs to
# - ExtendedSessionID - ID of the overall session that this scenario belongs to
# - UserID - ID of the user
# - ScenarioOrder - Order of the scenario in the session
#
# ### Scenario Details
# - Intervention - Whether the car swerves in this scenario
# - PedPed - Passengers vs Pedestrians (PedPed==0) or Pedestrians vs Pedestrians (PedPed==1)
# - Barrier - Whether the car will crash into the barrier in this scenario (only used in Passengers vs Pedestrians)
# - CrossingSignal - No crossing signal (CrossingSignal==0), crossing legally (CrossingSignal==1), crossing illegally (CrossingSignal==2)
#
# ### Scenario Type Metadata
# - AttributeLevel
# - ScenarioTypeStrict
# - ScenarioType
# - DefaultChoice
# - NonDefaultChoice
# - DefaultChoiceIsOmission
# - NumberOfCharacters
# - DiffNumberOFCharacters
#
# ### User Selection
# - Saved - Whether user chose to save this group of people (User selected other scenario as more preferable)
#
# ### User Metadata
# - Template - Template used (Desktop or Mobile)
# - DescriptionShown - Whether the user viewed the text description of the scenario
# - LeftHand - Whether this scenario was shown on the left side of the screen
# - UserCountry3 - Country of the user
#
# ### Scenario Demographics
# - Man
# - Woman
# - Pregnant
# - Stroller
# - OldMan
# - OldWoman
# - Boy
# - Girl
# - Homeless
# - LargeWoman
# - LargeMan
# - Criminal
# - MaleExecutive
# - FemaleExecutive
# - FemaleAthlete
# - MaleAthlete
# - FemaleDoctor
# - MaleDoctor
# - Dog
# - Cat

# %%
data.sort_values(['UserID', 'ExtendedSessionID', 'ScenarioOrder', 'ResponseID'], inplace=True)
data
# Out:
#                ResponseID              ExtendedSessionID            UserID  \
# 365622  ibLqM87ri8vF3zMZE             -101637185_1031125           1031125
# 365623  ibLqM87ri8vF3zMZE             -101637185_1031125           1031125
# 240075  TKf4myQBxQbP4wQN2             -101637185_1031125           1031125
# 240076  TKf4myQBxQbP4wQN2             -101637185_1031125           1031125
# 101706  Cib3BmjHh2bfgdtkR             -101637185_1031125           1031125
# ...                   ...                            ...               ...
# 380421  k7mmKxhT5cbMQRSXM  1495942421_9999785381485598.0  9999785381485600
# 323281  e9MY23PdSwvbtYAo4  1495942421_9999785381485598.0  9999785381485600
# 323282  e9MY23PdSwvbtYAo4  1495942421_9999785381485598.0  9999785381485600
# 136791  GPFQ4fMLTyG5gpeSL  1495942421_9999785381485598.0  9999785381485600
# 136792  GPFQ4fMLTyG5gpeSL  1495942421_9999785381485598.0  9999785381485600
#
#         ScenarioOrder  Intervention  PedPed  Barrier  CrossingSignal  \
# 365622              1             0       0        0               1
# 365623              1             1       0        1               0
# 240075              3             0       1        0               2
# 240076              3             1       1        0               1
# 101706              4             0       0        0               1
# ...               ...           ...     ...      ...             ...
# 380421             11             1       0        0               1
# 323281             12             0       0        0               2
# 323282             12             1       0        1               0
# 136791             13             0       0        0               0
# 136792             13             1       0        1               0
#
#        AttributeLevel ScenarioTypeStrict ScenarioType DefaultChoice  \
# 365622           Rand             Random       Random           NaN
# 365623           Rand             Random       Random           NaN
# 240075            Old                Age          Age         Young
# 240076          Young                Age          Age         Young
# 101706            Fat            Fitness      Fitness           Fit
# ...               ...                ...          ...           ...
# 380421         Female             Gender       Gender          Male
# 323281            Fit            Fitness      Fitness           Fit
# 323282            Fat            Fitness      Fitness           Fit
# 136791        Hoomans            Species      Species       Hoomans
# 136792           Pets            Species      Species       Hoomans
#
#        NonDefaultChoice  DefaultChoiceIsOmission  NumberOfCharacters  \
# 365622              NaN                      NaN                   1
# 365623              NaN                      NaN                   4
# 240075              Old                      0.0                   2
# 240076              Old                      0.0                   2
# 101706              Fat                      0.0                   3
# ...                 ...                      ...                 ...
# 380421           Female                      1.0                   4
# 323281              Fat                      1.0                   5
# 323282              Fat                      1.0                   5
# 136791             Pets                      1.0                   4
# 136792             Pets                      1.0                   4
#
#         DiffNumberOFCharacters  Saved Template  DescriptionShown  LeftHand  \
# 365622                       3      0  Desktop               0.0       1.0
# 365623                       3      1  Desktop               0.0       0.0
# 240075                       0      0  Desktop               1.0       0.0
# 240076                       0      1  Desktop               1.0       1.0
# 101706                       0      1  Desktop               0.0       0.0
# ...                        ...    ...      ...               ...       ...
# 380421                       0      0   Mobile               0.0       0.0
# 323281                       0      1   Mobile               0.0       1.0
# 323282                       0      0   Mobile               0.0       0.0
# 136791                       0      1   Mobile               0.0       0.0
# 136792                       0      0   Mobile               0.0       1.0
#
#        UserCountry3  Man  Woman  Pregnant  Stroller  OldMan  OldWoman  Boy  \
# 365622          SGP  0.0      0         0         0       0         0    0
# 365623          SGP  0.0      0         0         1       0         0    0
# 240075          SGP  0.0      0         0         0       1         1    0
# 240076          SGP  0.0      1         0         0       0         0    1
# 101706          SGP  0.0      1         0         0       0         0    0
# ...             ...  ...    ...       ...       ...     ...       ...  ...
# 380421          SGP  0.0      1         0         0       0         0    0
# 323281          SGP  0.0      2         0         0       0         0    0
# 323282          SGP  1.0      2         0         0       0         0    0
# 136791          SGP  0.0      0         0         0       1         0    0
# 136792          SGP  0.0      0         0         0       0         0    0
#
#         Girl  Homeless  LargeWoman  LargeMan  Criminal  MaleExecutive  \
# 365622     0         0           0         0         0              0
# 365623     1         0           0         0         0              0
# 240075     0         0           0         0         0              0
# 240076     0         0           0         0         0              0
# 101706     0         0           1         1         0              0
# ...      ...       ...         ...       ...       ...            ...
# 380421     0         0           0         0         0              0
# 323281     0         0           0         0         0              0
# 323282     0         0           2         0         0              0
# 136791     0         0           0         0         1              0
# 136792     0         0           0         0         0              0
#
#         FemaleExecutive  FemaleAthlete  MaleAthlete  FemaleDoctor  MaleDoctor  \
# 365622                0              0            0             0           0
# 365623                0              1            0             0           1
# 240075                0              0            0             0           0
# 240076                0              0            0             0           0
# 101706                0              0            0             0           0
# ...                 ...            ...          ...           ...         ...
# 380421                0              2            0             1           0
# 323281                0              2            1             0           0
# 323282                0              0            0             0           0
# 136791                0              0            0             1           1
# 136792                0              0            0             0           0
#
#         Dog  Cat
# 365622    1    0
# 365623    0    0
# 240075    0    0
# 240076    0    0
# 101706    0    0
# ...     ...  ...
# 380421    0    0
# 323281    0    0
# 323282    0    0
# 136791    0    0
# 136792    3    1
#
# [521470 rows x 41 columns]

# %% [markdown]
# ## Scenario Type Metadata

# %%
columns = [
    'ResponseID',
    'AttributeLevel',
    'ScenarioTypeStrict',
    'ScenarioType',
    'DefaultChoice',
    'NonDefaultChoice',
    'DefaultChoiceIsOmission',
]
data[columns]
# Out:
#                ResponseID AttributeLevel ScenarioTypeStrict ScenarioType  \
# 365622  ibLqM87ri8vF3zMZE           Rand             Random       Random
# 365623  ibLqM87ri8vF3zMZE           Rand             Random       Random
# 240075  TKf4myQBxQbP4wQN2            Old                Age          Age
# 240076  TKf4myQBxQbP4wQN2          Young                Age          Age
# 101706  Cib3BmjHh2bfgdtkR            Fat            Fitness      Fitness
# ...                   ...            ...                ...          ...
# 380421  k7mmKxhT5cbMQRSXM         Female             Gender       Gender
# 323281  e9MY23PdSwvbtYAo4            Fit            Fitness      Fitness
# 323282  e9MY23PdSwvbtYAo4            Fat            Fitness      Fitness
# 136791  GPFQ4fMLTyG5gpeSL        Hoomans            Species      Species
# 136792  GPFQ4fMLTyG5gpeSL           Pets            Species      Species
#
#        DefaultChoice NonDefaultChoice  DefaultChoiceIsOmission
# 365622           NaN              NaN                      NaN
# 365623           NaN              NaN                      NaN
# 240075         Young              Old                      0.0
# 240076         Young              Old                      0.0
# 101706           Fit              Fat                      0.0
# ...              ...              ...                      ...
# 380421          Male           Female                      1.0
# 323281           Fit              Fat                      1.0
# 323282           Fit              Fat                      1.0
# 136791       Hoomans             Pets                      1.0
# 136792       Hoomans             Pets                      1.0
#
# [521470 rows x 7 columns]

# %%
print(f"Passengers vs Pedestrians: {len(data[data['PedPed'] == 0])}")
print(f"Passengers vs Pedestrians with Barrier: {len(data[(data['PedPed'] == 0) & (data['Barrier'] == 1)])}")
print(f"Pedestrians vs Pedestrians with Barrier: {len(data[(data['PedPed'] == 1) & (data['Barrier'] == 1)])}")
# Out:
# Passengers vs Pedestrians: 286825
# Passengers vs Pedestrians with Barrier: 143287
# Pedestrians vs Pedestrians with Barrier: 0

# %%
print(f"No Crossing Signal with Barrier: {len(data[(data['CrossingSignal'] == 0) & (data['Barrier'] == 1)])}")
print(f"Crossing Signal with Barrier: {len(data[(data['CrossingSignal'] != 0) & (data['Barrier'] == 1)])}")
# Out:
# No Crossing Signal with Barrier: 143287
# Crossing Signal with Barrier: 0

# %%
columns = [
    'ResponseID',
    'UserCountry3',
    'Intervention',
    'PedPed',
    'Barrier',
    'CrossingSignal',
    'Man',
    'Woman',
    'Pregnant',
    'Stroller',
    'OldMan',
    'OldWoman',
    'Boy',
    'Girl',
    'Homeless',
    'LargeWoman',
    'LargeMan',
    'Criminal',
    'MaleExecutive',
    'FemaleExecutive',
    'FemaleAthlete',
    'MaleAthlete',
    'FemaleDoctor',
    'MaleDoctor',
    'Dog',
    'Cat',
    'Saved',
]
data[columns]
# Out:
#                ResponseID UserCountry3  Intervention  PedPed  Barrier  \
# 365622  ibLqM87ri8vF3zMZE          SGP             0       0        0
# 365623  ibLqM87ri8vF3zMZE          SGP             1       0        1
# 240075  TKf4myQBxQbP4wQN2          SGP             0       1        0
# 240076  TKf4myQBxQbP4wQN2          SGP             1       1        0
# 101706  Cib3BmjHh2bfgdtkR          SGP             0       0        0
# ...                   ...          ...           ...     ...      ...
# 380421  k7mmKxhT5cbMQRSXM          SGP             1       0        0
# 323281  e9MY23PdSwvbtYAo4          SGP             0       0        0
# 323282  e9MY23PdSwvbtYAo4          SGP             1       0        1
# 136791  GPFQ4fMLTyG5gpeSL          SGP             0       0        0
# 136792  GPFQ4fMLTyG5gpeSL          SGP             1       0        1
#
#         CrossingSignal  Saved  Man  Woman  Pregnant  Stroller  OldMan  \
# 365622               1      0  0.0      0         0         0       0
# 365623               0      1  0.0      0         0         1       0
# 240075               2      0  0.0      0         0         0       1
# 240076               1      1  0.0      1         0         0       0
# 101706               1      1  0.0      1         0         0       0
# ...                ...    ...  ...    ...       ...       ...     ...
# 380421               1      0  0.0      1         0         0       0
# 323281               2      1  0.0      2         0         0       0
# 323282               0      0  1.0      2         0         0       0
# 136791               0      1  0.0      0         0         0       1
# 136792               0      0  0.0      0         0         0       0
#
#         OldWoman  Boy  Girl  Homeless  LargeWoman  LargeMan  Criminal  \
# 365622         0    0     0         0           0         0         0
# 365623         0    0     1         0           0         0         0
# 240075         1    0     0         0           0         0         0
# 240076         0    1     0         0           0         0         0
# 101706         0    0     0         0           1         1         0
# ...          ...  ...   ...       ...         ...       ...       ...
# 380421         0    0     0         0           0         0         0
# 323281         0    0     0         0           0         0         0
# 323282         0    0     0         0           2         0         0
# 136791         0    0     0         0           0         0         1
# 136792         0    0     0         0           0         0         0
#
#         MaleExecutive  FemaleExecutive  FemaleAthlete  MaleAthlete  \
# 365622              0                0              0            0
# 365623              0                0              1            0
# 240075              0                0              0            0
# 240076              0                0              0            0
# 101706              0                0              0            0
# ...               ...              ...            ...          ...
# 380421              0                0              2            0
# 323281              0                0              2            1
# 323282              0                0              0            0
# 136791              0                0              0            0
# 136792              0                0              0            0
#
#         FemaleDoctor  MaleDoctor  Dog  Cat
# 365622             0           0    1    0
# 365623             0           1    0    0
# 240075             0           0    0    0
# 240076             0           0    0    0
# 101706             0           0    0    0
# ...              ...         ...  ...  ...
# 380421             1           0    0    0
# 323281             0           0    0    0
# 323282             0           0    0    0
# 136791             1           1    0    0
# 136792             0           0    3    1
#
# [521470 rows x 27 columns]
